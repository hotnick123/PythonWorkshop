# %%
class PyTestClass:
    """It's for Test Class"""
    pass

print(dir())
print(type(PyTestClass))
# Out:
# ['In', 'Out', 'PyTestClass', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'quit']
# <class 'type'>

# %%
class Person:
    Name = "Default"
    
    def Print(self):
        print("My name is {0}".format(self.Name))
        
p = Person()
p.Print()

p.Name = "파이썬3 테스트 클래스"
p.Print()
Person.Print(p)
# Out:
# My name is Default
# My name is 파이썬3 테스트 클래스
# My name is 파이썬3 테스트 클래스

# %%
p2 = Person()

print("p Name: ", p.Name)
print("p2 Name: ", p2.Name)

Person.title = "Python3 테스트"
print("p title: ", p.title)
print("p2 title: ", p2.title)
print("Person title: ", Person.title)

p.age = 20
print("p age: ", p.age)
# Out:
# p Name:  파이썬3 테스트 클래스
# p2 Name:  Default
# p title:  Python3 테스트
# p2 title:  Python3 테스트
# Person title:  Python3 테스트
# p age:  20

# %%
print("Person age: ", Person.age)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-fab5aa44c49c> in <module>
# ----> 1 print("Person age: ", Person.age)
#
# AttributeError: type object 'Person' has no attribute 'age'

# %%
str1 = "클래스 멤버 아님"

class NonSelfTest:
    str1 = ""
    
    def Set(self, msg):
        self.str1 = msg
        
    def Print(self):
        print(str1)
        
    def WhyUseSelfPrint(self):
        print(self.str1)
        
test = NonSelfTest()

test.Set("테스트 메세지")
test.Print()
test.WhyUseSelfPrint()
# Out:
# 클래스 멤버 아님
# 테스트 메세지

# %%
class Vehicles:
    def __init__(self, value):
        self.Value = value
        print("생성자! Value = ", value)
        
    def __del__(self):
        print("소멸자!")
        
def test():
    v = Vehicles(333);
    
test()
print("누가 먼저냐 ?")
# Out:
# 생성자! Value =  333
# 소멸자!
# 누가 먼저냐 ?

# %%
class Person:
    def __init__(self, name, phoneNum):
        self.name = name
        self.phoneNum = phoneNum
        
    def printInfo(self):
        print("Info(name: {0}, phone num: {1})".format(self.name, self.phoneNum))

# Java extends 상속
# Python은 클래스(상속할 클래스명)
class Student(Person):
    def __init__(self, name, phoneNum, subject, studentId):
        self.name = name
        self.phoneNum = phoneNum
        self.subject = subject
        self.studentId = studentId
        
p = Person("Maron", "045-607-1852")
s = Student("Lunar", "406-708-3821", "Electronic Engineering", "7283492")

p.printInfo()

print(p.__dict__)
print(s.__dict__)
# Out:
# Info(name: Maron, phone num: 045-607-1852)
# {'name': 'Maron', 'phoneNum': '045-607-1852'}
# {'name': 'Lunar', 'phoneNum': '406-708-3821', 'subject': 'Electronic Engineering', 'studentId': '7283492'}

# %%
# super() 활용법
class Parent(object):
    def __init__(self, number):
        self.Number = number
        
    def printMsg(self):
        print("I'm Super Class")
        
class Test(Parent):
    def __init__(self, number):
        super(Test, self).__init__(number)
        
    def printMsg(self):
        print("I'm Sub Class: [%s]" % str(self.Number))
        super(Test, self).printMsg()
        
c = Child(3)
c.printMsg()

print(c.__dict__)
# Out:
# I'm Sub Class: [3]
# I'm Super Class
# {'Number': 3}

# %%
# 파이썬 난수
from random import *

for i in range(20):
    rand_int = randint(1, 100) # 시작, 끝
    rand_float = random() # 0 ~ 1사이
    print(rand_int, rand_float)
# Out:
# 80 0.6561661846674225
# 23 0.3621524141833371
# 94 0.29102903406843894
# 17 0.49002262788163053
# 98 0.8714964406347329
# 68 0.8045740964141845
# 50 0.08471447334997362
# 33 0.6541631488669801
# 67 0.7293064041953055
# 55 0.5671680945028046
# 32 0.0496199324267832
# 68 0.6700622293627677
# 55 0.31090386479494836
# 68 0.23073014101700462
# 76 0.3592076992735156
# 2 0.332272168912069
# 3 0.3347023081254312
# 92 0.17265620554674777
# 13 0.8593165836841601
# 36 0.4060674404902156

# %%
# 숙제 1.
# 1 ~ 100까지의 숫자중 3의 배수만 추려서 출력하도록
# 클래스 및 매서드를 프로그래밍 하시오.

# %%
for i in range(1, 101):
    # i % 3 == 0 보다 비트 연산 not 이 더 빠름
    if (not(i % 3)):
        print('i = ', i)
# Out:
# i =  3
# i =  6
# i =  9
# i =  12
# i =  15
# i =  18
# i =  21
# i =  24
# i =  27
# i =  30
# i =  33
# i =  36
# i =  39
# i =  42
# i =  45
# i =  48
# i =  51
# i =  54
# i =  57
# i =  60
# i =  63
# i =  66
# i =  69
# i =  72
# i =  75
# i =  78
# i =  81
# i =  84
# i =  87
# i =  90
# i =  93
# i =  96
# i =  99

# %%
# 숙제 2.
# 주사위 게임을 플레이할 수 있도록 클래스 및 매서드를 작성하시오.
# 주사위는 1개만 굴리도록 하며 승패 판정은 누가 더 높은 주사위 눈금을 가지느냐에 따라 갈린다.

# %%
from random import *

class Dice:
    def __init__(self, player):
        self.player = player
        
    def run_dice(self):
        self.dice = randint(1, 6)
        print('{0} - 주사위 눈금은 {1}'.format(self.player, self.dice))
        
    def who_win(self, versus):
        if (self.dice > versus.dice):
            print("{0} 승리".format(self.player))
        elif (self.dice < versus.dice):
            print("{0} 승리".format(versus.player))
        else:
            print("비김 {0} vs {1}".format(self.dice, versus.dice))
            
    def get_dice(self):
        return self.dice

player1 = Dice('플레이어1')
player1.run_dice()

player2 = Dice('플레이어2')
player2.run_dice()

player1.who_win(player2)
player2.who_win(player1)
# Out:
# 플레이어1 - 주사위 눈금은 2
# 플레이어2 - 주사위 눈금은 3
# 플레이어2 승리
# 플레이어2 승리

# %%
# 숙제 3.
# 가상의 보드 게임을 만든다.
# 한 바퀴를 도는데 총 주사위 눈금이 40칸 필요하다.
# 1) 한 바퀴를 돌면 자금으로 100만원이 주어진다.
# 2) 주사위의 특수 능력을 활용할 수 있다.
#    2-1) 숫자 2: 모두의 자금에서 50만원을 깐다.
#    2-2) 숫자 4: 자신의 자금의 5%가 증발한다.
#    2-3) 숫자 6: 모두의 자금에 30만원을 추가한다.
#    2-4) 모든 플레이어들이 주사위를 돌린 눈금이 짝수일 경우 비밀 상점이 열린다.
#         비밀 상점 물품: 레드 티켓(지정한 상대의 주사위가 5턴 동안 정지함) - 100만원
#                        옐로 티켓(지정한 상대ㅢ 주사위가 2턴간 정지함) - 50만원
#                        카오스 티켓(아무나 한 명 2턴간 정지함) - 10만원
#                        뽑기 티켓(1만원, 2만원, 5만원, 10만원, 20만원, 50만원, 100만원) - 10만원
#                        연속 굴리기(1회, 2회, 3회, 4회) - 20만원
#    2-5) 플레이어가 필드를 3바퀴 돌면 게임이 종료된다. (주사위 눈금 총 120칸 필요)
#    2-6) 게임이 종료된 이후 가장 많은 자금을 가지고 있는 사람이 경기에 승리하게 된다.
# 게임 팁: 1) 일단 돈을 많이 모은다
#          2) 비밀 상점을 활용하여 대박(뽑기)을 노리거나 상대방을 행동 불능에 빠지게 한다.
#          3) 유리한 상황에서 연속 굴리기를 통해 게임을 빠르게 끝내도록 유도한다.
#          4) 다수가 함께 플레이 할 경우 연속 굴리기를 통해 정치도 가능하다 ?
#          5) 적자대전의 경우 숫자 4를 확보하는 것이 유리할 수 있다.

# %%
def value_support(x):
    return x[1]

# %%
# 1) Game 클래스
#    1-1) 게임을 종료할 상황인지 판정
#    1-2) 비밀 상점 온/오프 판정
#    1-3) 승리자 판정
#    1-4) 비밀 상점 물품 사용 판정
#    1-5) 광역 스킬 시전 판정
# 2) Player 클래스
# 3) Dice 클래스 (2번 문제 코드 재활용)

class Game:
    def __init__(self):
        self.secret_store = False
        self.game_end = False
        self.use_chaos_ticket = False
        self.player_arr = []
        self.dice_sum = 0
        
    def open_secret_store(self):
        print("비밀 상점이 열렸으니 플레이어들은 물품을 구매해주세요!!!")
        # TODO: 숙제
        # 비밀 상점 기능은 실제 루프 돌면서 주사위를 돌리는 플레이어들의 행동을 제한해야함
        # 혹은 연속 돌리기 기능의 경우 다른 플레이어들은 정지 상태로 자신만 돌아야함
        
    def dice_skill(self, player_arr, player_info, cur_dice):
        print("{0} - 주사위 스킬이 발동됩니다!".format(player_info.player))

        # 파이썬에는 switch가 없으므로 if로 구현해야함!
        if cur_dice == 2:
            print("모두의 자금에서 50만원을 깐다.")
            
            for i in range(len(player_arr)):
                player_arr[i].withdraw(500000)
        elif cur_dice == 4:
            print("자신의 자금의 5%가 증발한다.")
            # TODO: 숙제
            player_info.withdraw_percent(5)
        elif cur_dice == 6:
            print("모두의 자금에 30만원을 추가한다.")
            
            for i in range(len(player_arr)):
                player_arr[i].deposit(300000)
        
        
    def start_game(self):
        self.player = int(input("몇 명이 플레이 하는 게임입니꽈 ? "))
        
        for i in range(self.player):
            name = input("플레이어 이름을 적어주세요")
            self.player_arr.append(Player(name))
            
        while (not(self.game_end)):
            for i in range(self.player):
                self.player_arr[i].run_dice()
                cur_dice = self.player_arr[i].get_dice()
                self.dice_sum += cur_dice
                
                if (not(cur_dice % 2)):
                    self.dice_skill(self.player_arr, self.player_arr[i], cur_dice)
                    
                self.player_arr[i].update_location(cur_dice)
                    
                if (self.player_arr[i].get_lap() == 3):
                    self.game_end = True
                    break
                    
            if (self.game_end):
                break
                
            if (not(self.dice_sum % 2)):
                self.open_secret_store()
                
            self.dice_sum = 0
            
        # 정산을 통해 승자 판정(게임을 먼저 끝내도 4번만 나왔으면 질 수도 있음)
        # TODO: 숙제
        # map
        # "이름": 값, "이름": 값
        # 키: 밸류, 키: 밸류
        income = {}
        
        for i in range(len(self.player_arr)):
            print(self.player_arr[i].__dict__)
            
            # 가만보니 이 코드엔 숨겨진 문제가 있음
            # 뭘까요 ?
            # 1) 이 코드의 목적은 무엇인가 ? 결국 정산을 통해 승자를 판정하는 것임
            # 2) 이 코드는 income(수입)이 가장 높은 경우만 찾음(승자를 찾지 못함)
            #income.append(self.palyer_arr[i].get_money())
            
            income[self.player_arr[i].get_player()] = self.player_arr[i].get_money()
            
        print("income: ", income)
        
        # 위의 문제되는 케이스는 Map을 통해 제거했고
        # 추가적으로 value 기반 정렬을 통해 값이 큰 녀석으로 정렬이 가능
        sorted_income = sorted(income.items(), key=value_support, reverse=True)
        
        print("income: ", sorted_income)
        
        print("최종 승자: {0}".format(sorted_income[0]))
        
class Player(Dice):
    def __init__(self, player):
        super(Player, self).__init__(player)
        # 몇 바퀴 돌았는지
        self.lap = 0
        # 현재 위치
        self.location = 0
        # 소지금
        self.money = 0
        
        print("Player 생성자 호출!")
        
    def update_location(self, dice):
        self.location += dice
        
        if (self.location >= 40):
            self.location -= 40
            self.lap += 1
            
            self.money += 1000000
            
        print("위치값 갱신 lap - {0}, location - {1}".format(self.lap, self.location))
            
    def get_lap(self):
        return self.lap
        
    def withdraw(self, money):
        self.money -= money
        print("출금: 내돈 = {0}".format(self.money))
        
    def deposit(self, money):
        self.money += money
        print("입금: 내돈 = {0}".format(self.money))
        
    def withdraw_percent(self, percent):
        #self.money = self.money - self.money * 5 / 100
        #self.money = self.money * (1 - 5 / 100)
        #self.money -= self.money * (5 / 100)
        # a x b = ab
        self.money -= self.money * percent / 100
        print("퍼센트 출금: 내돈 = {0}".format(self.money))
        
    def get_money(self):
        return self.money
    
    def get_player(self):
        return self.player
        
board_game = Game()
board_game.start_game()

print(board_game.__dict__)
# Out:
# 몇 명이 플레이 하는 게임입니꽈 ? 4
# 플레이어 이름을 적어주세요t1
# Player 생성자 호출!
# 플레이어 이름을 적어주세요t2
# Player 생성자 호출!
# 플레이어 이름을 적어주세요t3
# Player 생성자 호출!
# 플레이어 이름을 적어주세요t4
# Player 생성자 호출!
# t1 - 주사위 눈금은 1
# 위치값 갱신 lap - 0, location - 1
# t2 - 주사위 눈금은 2
# t2 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = -500000
# 출금: 내돈 = -500000
# 출금: 내돈 = -500000
# 출금: 내돈 = -500000
# 위치값 갱신 lap - 0, location - 2
# t3 - 주사위 눈금은 5
# 위치값 갱신 lap - 0, location - 5
# t4 - 주사위 눈금은 2
# t4 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = -1000000
# 출금: 내돈 = -1000000
# 출금: 내돈 = -1000000
# 출금: 내돈 = -1000000
# 위치값 갱신 lap - 0, location - 2
# 비밀 상점이 열렸으니 플레이어들은 물품을 구매해주세요!!!
# t1 - 주사위 눈금은 3
# 위치값 갱신 lap - 0, location - 4
# t2 - 주사위 눈금은 5
# 위치값 갱신 lap - 0, location - 7
# t3 - 주사위 눈금은 5
# 위치값 갱신 lap - 0, location - 10
# t4 - 주사위 눈금은 6
# t4 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = -700000
# 입금: 내돈 = -700000
# 입금: 내돈 = -700000
# 입금: 내돈 = -700000
# 위치값 갱신 lap - 0, location - 8
# t1 - 주사위 눈금은 3
# 위치값 갱신 lap - 0, location - 7
# t2 - 주사위 눈금은 5
# 위치값 갱신 lap - 0, location - 12
# t3 - 주사위 눈금은 2
# t3 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = -1200000
# 출금: 내돈 = -1200000
# 출금: 내돈 = -1200000
# 출금: 내돈 = -1200000
# 위치값 갱신 lap - 0, location - 12
# t4 - 주사위 눈금은 5
# 위치값 갱신 lap - 0, location - 13
# t1 - 주사위 눈금은 5
# 위치값 갱신 lap - 0, location - 12
# t2 - 주사위 눈금은 6
# t2 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = -900000
# 입금: 내돈 = -900000
# 입금: 내돈 = -900000
# 입금: 내돈 = -900000
# 위치값 갱신 lap - 0, location - 18
# t3 - 주사위 눈금은 3
# 위치값 갱신 lap - 0, location - 15
# t4 - 주사위 눈금은 5
# 위치값 갱신 lap - 0, location - 18
# t1 - 주사위 눈금은 3
# 위치값 갱신 lap - 0, location - 15
# t2 - 주사위 눈금은 3
# 위치값 갱신 lap - 0, location - 21
# t3 - 주사위 눈금은 2
# t3 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = -1400000
# 출금: 내돈 = -1400000
# 출금: 내돈 = -1400000
# 출금: 내돈 = -1400000
# 위치값 갱신 lap - 0, location - 17
# t4 - 주사위 눈금은 2
# t4 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = -1900000
# 출금: 내돈 = -1900000
# 출금: 내돈 = -1900000
# 출금: 내돈 = -1900000
# 위치값 갱신 lap - 0, location - 20
# 비밀 상점이 열렸으니 플레이어들은 물품을 구매해주세요!!!
# t1 - 주사위 눈금은 3
# 위치값 갱신 lap - 0, location - 18
# t2 - 주사위 눈금은 5
# 위치값 갱신 lap - 0, location - 26
# t3 - 주사위 눈금은 5
# 위치값 갱신 lap - 0, location - 22
# t4 - 주사위 눈금은 6
# t4 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = -1600000
# 입금: 내돈 = -1600000
# 입금: 내돈 = -1600000
# 입금: 내돈 = -1600000
# 위치값 갱신 lap - 0, location - 26
# t1 - 주사위 눈금은 6
# t1 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = -1300000
# 입금: 내돈 = -1300000
# 입금: 내돈 = -1300000
# 입금: 내돈 = -1300000
# 위치값 갱신 lap - 0, location - 24
# t2 - 주사위 눈금은 2
# t2 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = -1800000
# 출금: 내돈 = -1800000
# 출금: 내돈 = -1800000
# 출금: 내돈 = -1800000
# 위치값 갱신 lap - 0, location - 28
# t3 - 주사위 눈금은 4
# t3 - 주사위 스킬이 발동됩니다!
# 자신의 자금의 5%가 증발한다.
# 퍼센트 출금: 내돈 = -1710000.0
# 위치값 갱신 lap - 0, location - 26
# t4 - 주사위 눈금은 1
# 위치값 갱신 lap - 0, location - 27
# t1 - 주사위 눈금은 6
# t1 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = -1500000
# 입금: 내돈 = -1500000
# 입금: 내돈 = -1410000.0
# 입금: 내돈 = -1500000
# 위치값 갱신 lap - 0, location - 30
# t2 - 주사위 눈금은 4
# t2 - 주사위 스킬이 발동됩니다!
# 자신의 자금의 5%가 증발한다.
# 퍼센트 출금: 내돈 = -1425000.0
# 위치값 갱신 lap - 0, location - 32
# t3 - 주사위 눈금은 1
# 위치값 갱신 lap - 0, location - 27
# t4 - 주사위 눈금은 6
# t4 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = -1200000
# 입금: 내돈 = -1125000.0
# 입금: 내돈 = -1110000.0
# 입금: 내돈 = -1200000
# 위치값 갱신 lap - 0, location - 33
# t1 - 주사위 눈금은 3
# 위치값 갱신 lap - 0, location - 33
# t2 - 주사위 눈금은 5
# 위치값 갱신 lap - 0, location - 37
# t3 - 주사위 눈금은 5
# 위치값 갱신 lap - 0, location - 32
# t4 - 주사위 눈금은 6
# t4 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = -900000
# 입금: 내돈 = -825000.0
# 입금: 내돈 = -810000.0
# 입금: 내돈 = -900000
# 위치값 갱신 lap - 0, location - 39
# t1 - 주사위 눈금은 2
# t1 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = -1400000
# 출금: 내돈 = -1325000.0
# 출금: 내돈 = -1310000.0
# 출금: 내돈 = -1400000
# 위치값 갱신 lap - 0, location - 35
# t2 - 주사위 눈금은 4
# t2 - 주사위 스킬이 발동됩니다!
# 자신의 자금의 5%가 증발한다.
# 퍼센트 출금: 내돈 = -1258750.0
# 위치값 갱신 lap - 1, location - 1
# t3 - 주사위 눈금은 6
# t3 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = -1100000
# 입금: 내돈 = 41250.0
# 입금: 내돈 = -1010000.0
# 입금: 내돈 = -1100000
# 위치값 갱신 lap - 0, location - 38
# t4 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 2
# t1 - 주사위 눈금은 5
# 위치값 갱신 lap - 1, location - 0
# t2 - 주사위 눈금은 1
# 위치값 갱신 lap - 1, location - 2
# t3 - 주사위 눈금은 6
# t3 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = 200000
# 입금: 내돈 = 341250.0
# 입금: 내돈 = -710000.0
# 입금: 내돈 = 200000
# 위치값 갱신 lap - 1, location - 4
# t4 - 주사위 눈금은 2
# t4 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = -300000
# 출금: 내돈 = -158750.0
# 출금: 내돈 = -210000.0
# 출금: 내돈 = -300000
# 위치값 갱신 lap - 1, location - 4
# 비밀 상점이 열렸으니 플레이어들은 물품을 구매해주세요!!!
# t1 - 주사위 눈금은 5
# 위치값 갱신 lap - 1, location - 5
# t2 - 주사위 눈금은 5
# 위치값 갱신 lap - 1, location - 7
# t3 - 주사위 눈금은 6
# t3 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = 0
# 입금: 내돈 = 141250.0
# 입금: 내돈 = 90000.0
# 입금: 내돈 = 0
# 위치값 갱신 lap - 1, location - 10
# t4 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 7
# t1 - 주사위 눈금은 5
# 위치값 갱신 lap - 1, location - 10
# t2 - 주사위 눈금은 4
# t2 - 주사위 스킬이 발동됩니다!
# 자신의 자금의 5%가 증발한다.
# 퍼센트 출금: 내돈 = 134187.5
# 위치값 갱신 lap - 1, location - 11
# t3 - 주사위 눈금은 6
# t3 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = 300000
# 입금: 내돈 = 434187.5
# 입금: 내돈 = 390000.0
# 입금: 내돈 = 300000
# 위치값 갱신 lap - 1, location - 16
# t4 - 주사위 눈금은 5
# 위치값 갱신 lap - 1, location - 12
# 비밀 상점이 열렸으니 플레이어들은 물품을 구매해주세요!!!
# t1 - 주사위 눈금은 1
# 위치값 갱신 lap - 1, location - 11
# t2 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 14
# t3 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 19
# t4 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 15
# 비밀 상점이 열렸으니 플레이어들은 물품을 구매해주세요!!!
# t1 - 주사위 눈금은 5
# 위치값 갱신 lap - 1, location - 16
# t2 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 17
# t3 - 주사위 눈금은 6
# t3 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = 600000
# 입금: 내돈 = 734187.5
# 입금: 내돈 = 690000.0
# 입금: 내돈 = 600000
# 위치값 갱신 lap - 1, location - 25
# t4 - 주사위 눈금은 4
# t4 - 주사위 스킬이 발동됩니다!
# 자신의 자금의 5%가 증발한다.
# 퍼센트 출금: 내돈 = 570000.0
# 위치값 갱신 lap - 1, location - 19
# 비밀 상점이 열렸으니 플레이어들은 물품을 구매해주세요!!!
# t1 - 주사위 눈금은 4
# t1 - 주사위 스킬이 발동됩니다!
# 자신의 자금의 5%가 증발한다.
# 퍼센트 출금: 내돈 = 570000.0
# 위치값 갱신 lap - 1, location - 20
# t2 - 주사위 눈금은 2
# t2 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = 70000.0
# 출금: 내돈 = 234187.5
# 출금: 내돈 = 190000.0
# 출금: 내돈 = 70000.0
# 위치값 갱신 lap - 1, location - 19
# t3 - 주사위 눈금은 1
# 위치값 갱신 lap - 1, location - 26
# t4 - 주사위 눈금은 2
# t4 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = -430000.0
# 출금: 내돈 = -265812.5
# 출금: 내돈 = -310000.0
# 출금: 내돈 = -430000.0
# 위치값 갱신 lap - 1, location - 21
# t1 - 주사위 눈금은 1
# 위치값 갱신 lap - 1, location - 21
# t2 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 22
# t3 - 주사위 눈금은 5
# 위치값 갱신 lap - 1, location - 31
# t4 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 24
# 비밀 상점이 열렸으니 플레이어들은 물품을 구매해주세요!!!
# t1 - 주사위 눈금은 2
# t1 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = -930000.0
# 출금: 내돈 = -765812.5
# 출금: 내돈 = -810000.0
# 출금: 내돈 = -930000.0
# 위치값 갱신 lap - 1, location - 23
# t2 - 주사위 눈금은 1
# 위치값 갱신 lap - 1, location - 23
# t3 - 주사위 눈금은 6
# t3 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = -630000.0
# 입금: 내돈 = -465812.5
# 입금: 내돈 = -510000.0
# 입금: 내돈 = -630000.0
# 위치값 갱신 lap - 1, location - 37
# t4 - 주사위 눈금은 2
# t4 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = -1130000.0
# 출금: 내돈 = -965812.5
# 출금: 내돈 = -1010000.0
# 출금: 내돈 = -1130000.0
# 위치값 갱신 lap - 1, location - 26
# t1 - 주사위 눈금은 2
# t1 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = -1630000.0
# 출금: 내돈 = -1465812.5
# 출금: 내돈 = -1510000.0
# 출금: 내돈 = -1630000.0
# 위치값 갱신 lap - 1, location - 25
# t2 - 주사위 눈금은 6
# t2 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = -1330000.0
# 입금: 내돈 = -1165812.5
# 입금: 내돈 = -1210000.0
# 입금: 내돈 = -1330000.0
# 위치값 갱신 lap - 1, location - 29
# t3 - 주사위 눈금은 6
# t3 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = -1030000.0
# 입금: 내돈 = -865812.5
# 입금: 내돈 = -910000.0
# 입금: 내돈 = -1030000.0
# 위치값 갱신 lap - 2, location - 3
# t4 - 주사위 눈금은 5
# 위치값 갱신 lap - 1, location - 31
# t1 - 주사위 눈금은 1
# 위치값 갱신 lap - 1, location - 26
# t2 - 주사위 눈금은 2
# t2 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = -1530000.0
# 출금: 내돈 = -1365812.5
# 출금: 내돈 = -410000.0
# 출금: 내돈 = -1530000.0
# 위치값 갱신 lap - 1, location - 31
# t3 - 주사위 눈금은 4
# t3 - 주사위 스킬이 발동됩니다!
# 자신의 자금의 5%가 증발한다.
# 퍼센트 출금: 내돈 = -389500.0
# 위치값 갱신 lap - 2, location - 7
# t4 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 34
# 비밀 상점이 열렸으니 플레이어들은 물품을 구매해주세요!!!
# t1 - 주사위 눈금은 4
# t1 - 주사위 스킬이 발동됩니다!
# 자신의 자금의 5%가 증발한다.
# 퍼센트 출금: 내돈 = -1453500.0
# 위치값 갱신 lap - 1, location - 30
# t2 - 주사위 눈금은 6
# t2 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = -1153500.0
# 입금: 내돈 = -1065812.5
# 입금: 내돈 = -89500.0
# 입금: 내돈 = -1230000.0
# 위치값 갱신 lap - 1, location - 37
# t3 - 주사위 눈금은 6
# t3 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = -853500.0
# 입금: 내돈 = -765812.5
# 입금: 내돈 = 210500.0
# 입금: 내돈 = -930000.0
# 위치값 갱신 lap - 2, location - 13
# t4 - 주사위 눈금은 6
# t4 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = -553500.0
# 입금: 내돈 = -465812.5
# 입금: 내돈 = 510500.0
# 입금: 내돈 = -630000.0
# 위치값 갱신 lap - 2, location - 0
# 비밀 상점이 열렸으니 플레이어들은 물품을 구매해주세요!!!
# t1 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 33
# t2 - 주사위 눈금은 1
# 위치값 갱신 lap - 1, location - 38
# t3 - 주사위 눈금은 6
# t3 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = -253500.0
# 입금: 내돈 = -165812.5
# 입금: 내돈 = 810500.0
# 입금: 내돈 = 670000.0
# 위치값 갱신 lap - 2, location - 19
# t4 - 주사위 눈금은 1
# 위치값 갱신 lap - 2, location - 1
# t1 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 36
# t2 - 주사위 눈금은 5
# 위치값 갱신 lap - 2, location - 3
# t3 - 주사위 눈금은 5
# 위치값 갱신 lap - 2, location - 24
# t4 - 주사위 눈금은 4
# t4 - 주사위 스킬이 발동됩니다!
# 자신의 자금의 5%가 증발한다.
# 퍼센트 출금: 내돈 = 636500.0
# 위치값 갱신 lap - 2, location - 5
# t1 - 주사위 눈금은 4
# t1 - 주사위 스킬이 발동됩니다!
# 자신의 자금의 5%가 증발한다.
# 퍼센트 출금: 내돈 = -240825.0
# 위치값 갱신 lap - 2, location - 0
# t2 - 주사위 눈금은 2
# t2 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = 259175.0
# 출금: 내돈 = 334187.5
# 출금: 내돈 = 310500.0
# 출금: 내돈 = 136500.0
# 위치값 갱신 lap - 2, location - 5
# t3 - 주사위 눈금은 6
# t3 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = 559175.0
# 입금: 내돈 = 634187.5
# 입금: 내돈 = 610500.0
# 입금: 내돈 = 436500.0
# 위치값 갱신 lap - 2, location - 30
# t4 - 주사위 눈금은 4
# t4 - 주사위 스킬이 발동됩니다!
# 자신의 자금의 5%가 증발한다.
# 퍼센트 출금: 내돈 = 414675.0
# 위치값 갱신 lap - 2, location - 9
# 비밀 상점이 열렸으니 플레이어들은 물품을 구매해주세요!!!
# t1 - 주사위 눈금은 4
# t1 - 주사위 스킬이 발동됩니다!
# 자신의 자금의 5%가 증발한다.
# 퍼센트 출금: 내돈 = 531216.25
# 위치값 갱신 lap - 2, location - 4
# t2 - 주사위 눈금은 6
# t2 - 주사위 스킬이 발동됩니다!
# 모두의 자금에 30만원을 추가한다.
# 입금: 내돈 = 831216.25
# 입금: 내돈 = 934187.5
# 입금: 내돈 = 910500.0
# 입금: 내돈 = 714675.0
# 위치값 갱신 lap - 2, location - 11
# t3 - 주사위 눈금은 5
# 위치값 갱신 lap - 2, location - 35
# t4 - 주사위 눈금은 3
# 위치값 갱신 lap - 2, location - 12
# 비밀 상점이 열렸으니 플레이어들은 물품을 구매해주세요!!!
# t1 - 주사위 눈금은 5
# 위치값 갱신 lap - 2, location - 9
# t2 - 주사위 눈금은 2
# t2 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = 331216.25
# 출금: 내돈 = 434187.5
# 출금: 내돈 = 410500.0
# 출금: 내돈 = 214675.0
# 위치값 갱신 lap - 2, location - 13
# t3 - 주사위 눈금은 4
# t3 - 주사위 스킬이 발동됩니다!
# 자신의 자금의 5%가 증발한다.
# 퍼센트 출금: 내돈 = 389975.0
# 위치값 갱신 lap - 2, location - 39
# t4 - 주사위 눈금은 4
# t4 - 주사위 스킬이 발동됩니다!
# 자신의 자금의 5%가 증발한다.
# 퍼센트 출금: 내돈 = 203941.25
# 위치값 갱신 lap - 2, location - 16
# t1 - 주사위 눈금은 3
# 위치값 갱신 lap - 2, location - 12
# t2 - 주사위 눈금은 2
# t2 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = -168783.75
# 출금: 내돈 = -65812.5
# 출금: 내돈 = -110025.0
# 출금: 내돈 = -296058.75
# 위치값 갱신 lap - 2, location - 15
# t3 - 주사위 눈금은 2
# t3 - 주사위 스킬이 발동됩니다!
# 모두의 자금에서 50만원을 깐다.
# 출금: 내돈 = -668783.75
# 출금: 내돈 = -565812.5
# 출금: 내돈 = -610025.0
# 출금: 내돈 = -796058.75
# 위치값 갱신 lap - 3, location - 1
# {'player': 't1', 'lap': 2, 'location': 12, 'money': -668783.75, 'dice': 3}
# {'player': 't2', 'lap': 2, 'location': 15, 'money': -565812.5, 'dice': 2}
# {'player': 't3', 'lap': 3, 'location': 1, 'money': 389975.0, 'dice': 2}
# {'player': 't4', 'lap': 2, 'location': 16, 'money': -796058.75, 'dice': 4}
# income:  {'t1': -668783.75, 't2': -565812.5, 't3': 389975.0, 't4': -796058.75}
# income:  [('t3', 389975.0), ('t2', -565812.5), ('t1', -668783.75), ('t4', -796058.75)]
# 최종 승자: ('t3', 389975.0)
# {'secret_store': False, 'game_end': True, 'use_chaos_ticket': False, 'player_arr': [<__main__.Player object at 0x000001DF379E1280>, <__main__.Player object at 0x000001DF379B3820>, <__main__.Player object at 0x000001DF37BA59D0>, <__main__.Player object at 0x000001DF379DC400>], 'dice_sum': 7, 'player': 4}
